# %% [markdown]
# # Bar Chart

# %% [raw]
# Bar Graph:
# =========
#
# A diagram that uses narrow bands of different heights to show different  amounts that they can be compared
#
# A bargarph is used to show the comparison among categories. It may consists of two or more parallel vertical or horizontal bars.
#
# In a bar chart , a bar shows each category , the length of which represents the amount , frequency or percentage of values falling into a category.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
company = ['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]

# %%
xpos=np.arange(len(company))

# %%
plt.bar(xpos,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.xticks(xpos,company)
plt.bar(xpos,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.title('Us Tech Stocks')
plt.xlabel('CompanyName')
plt.ylabel('Revenue($bl)')
plt.xticks(xpos,company)
plt.bar(xpos,revenue,label='Revenue')
plt.legend()

# %% [markdown]
# # Horizontal bar chart

# %%
plt.title('Us Tech Stocks')
plt.xlabel('Revenue($bl)')
plt.ylabel('CompanyName')
plt.yticks(xpos,company)

plt.barh(xpos,revenue,label='Revenue')
# Out:
# <BarContainer object of 4 artists>
